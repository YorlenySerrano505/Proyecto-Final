# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandasql as ps
import time 
import numpy as np
from selenium import webdriver
aux=pd.DataFrame()
aux.to_excel("df_proyecto.xlsx",index=False)        # | Creamos un documento Excel donde se guardara la informacion de los productos buscados

def Buscador_Precios_FGuadalajara(producto,mypath):         # | Creamos una funcion que buscara medicamentos en Farmacia Guadalajara
    
    path = mypath                                           # | Creamos lo pertinente para que el programa busque en el repectivo Chrome y el URL
    driver=webdriver.Chrome(path)
    url= "https://www.farmaciasguadalajara.com/SearchDisplay?categoryId=&storeId=10151&searchType=1001&catalogId=10052&langId=-24&sType=SimpleSearch&resultCatEntryType=2&showResultsPage=true&searchSource=Q&pageView=&beginIndex=0&pageSize=20&searchTerm="+producto
    driver.get(url)
        
    productos= driver.find_elements_by_class_name("product_info")    # | Este es la clase que almacena toda la informacion del producto
    ### accedemos a las urls almacenadas en la variable productos

    lista_urls=list()
    for i in range(len(productos)):
        try:
            lista_urls.append(productos[i].find_element_by_tag_name("a").get_attribute("href"))
        except:
            lista_urls.append(np.nan)
            
    ### Accedemos a los nombres de los productos

    lista_nombres=list()

    for i in range(len(productos)):
        try:
            lista_nombres.append(productos[i].find_elements_by_tag_name("a")[0].text)
        except:
            lista_nombres.append(np.nan)
     
    ### Accedemos a los precios de los productos
    
    lista_precios1=list()

    for i in range(len(productos)):
        try:
            lista_precios1.append(productos[i].find_elements_by_class_name("product_price")[0].text.split("\n"))
        except:
            lista_precios1.append(np.nan)
    
    ### Como los precios salen en una lista juntos, lo separamos en distintas listas
    
    lista_precios=list()
    lista_promos=list()

    for i in range(len(productos)):
        try:
            lista_precios.append(lista_precios1[i][0])
        except:
            lista_precios.append(np.nan)

    for i in range(len(productos)):
        try:
            lista_promos.append(lista_precios1[i][1])
        except:
            lista_promos.append(np.nan)
    
    
    ### Pasamos toda la informacion de los productos a al documento Excel
    df_proyecto = pd.DataFrame({"Nombre":lista_nombres,"URL":lista_urls,"Precio":lista_precios,"Precio con descuento":lista_promos})
    df_proyecto["Farmacia"]="Guadalajara"
    df_proyecto["Medicamento"]= producto
    df_proyecto["Fecha"]= time.strftime("%d/%m/%y")
    df_proyecto = df_proyecto[["Fecha","Farmacia","Medicamento","Nombre","URL","Precio","Precio con descuento"]]
    ### Una vez pasado convertimos la info a flotante y cerramos la ventana de Chrome
    datos_webscraper=pd.read_excel("df_proyecto.xlsx")
    datos_webscraper= pd.concat([datos_webscraper,df_proyecto],axis=0)
    datos_webscraper.to_excel("df_proyecto.xlsx",index=False)
    driver.quit()
    return df_proyecto

def Buscador_Precios_Selenium_sanpablo(producto,mypath):        # | Creamos una funcion que buscara medicamentos en Farmacia San Pablo
    
    path = mypath                                               # | Creamos lo pertinente para que el programa busque en el repectivo Chrome y el URL
    driver=webdriver.Chrome(path)
    url= "https://www.farmaciasanpablo.com.mx/search/?text="+producto 
    driver.get(url)

    productos= driver.find_elements_by_class_name("item")   # | Este es la clase que almacena toda la informacion del producto
    
    ### accedemos a las urls almacenadas en la variable productos
    
    lista_urls=[]
    for i in range(len(productos)):
        try:
            lista_urls.append(productos[i].find_element_by_tag_name("a").get_attribute("href"))
        except:
            lista_urls.append(np.nan)
            
    ### Accedemos a los precios de los productos
    
    lista_precios=[]
    lista_promos=[]
    for i in range(len(productos)):
        try:
            lista_precios.append(productos[i].find_elements_by_class_name("item-prize")[0].text)
        except:
            lista_precios.append(np.nan)
        try:
            lista_promos.append(productos[i].find_elements_by_class_name("item-prize")[1].text)
        except:
            lista_promos.append(np.nan)

    ### Accedemos a los nombres de los productos    

    lista_nombres=[]
    for i in range(len(productos)):
        try:
            lista_nombres.append(productos[i].find_elements_by_tag_name("a")[1].text)
        except:
            lista_nombres.append(np.nan)
    
    ### Pasamos toda la informacion de los productos a al documento Excel

    df_proyecto = pd.DataFrame({"Nombre":lista_nombres,"URL":lista_urls,"Precio":lista_precios,"Precio con descuento":lista_promos})
    df_proyecto["Farmacia"]="San Pablo"
    df_proyecto["Medicamento"]= producto
    df_proyecto["Fecha"]= time.strftime("%d/%m/%y")
    df_proyecto = df_proyecto[["Fecha","Farmacia","Medicamento","Nombre","URL","Precio","Precio con descuento"]]
    
    
    ### Una vez pasado convertimos la info a flotante y cerramos la ventana de Chrome
    
    df_proyecto = df_proyecto[df_proyecto["Nombre"].astype(str).str.contains(r'\b{}\b'.format(producto), regex=True, case=False)]
    df_proyecto  =df_proyecto.reset_index(drop=True)
    datos_webscraper=pd.read_excel("df_proyecto.xlsx")
    datos_webscraper= pd.concat([datos_webscraper,df_proyecto],axis=0)
    datos_webscraper.to_excel("df_proyecto.xlsx",index=False)
    driver.quit()
    return df_proyecto


def Buscador_Precios_Selenium_FAhorro(producto,mypath):              # | Creamos una funcion que buscara medicamentos en Farmacia Del Ahorro
    path = mypath
    driver=webdriver.Chrome(path)
    url= "https://www.fahorro.com/catalogsearch/result/?q="+producto        # | Creamos lo pertinente para que el programa busque en el repectivo Chrome y el URL
    driver.get(url)
    
    productos= driver.find_elements_by_class_name("product-item-info") # | Este es la clase que almacena toda la informacion del producto

    ### accedemos a las urls almacenadas en la variable productos

    lista_urls=list()
    for i in range(len(productos)):
        try:
            lista_urls.append(productos[i].find_element_by_tag_name("a").get_attribute("href"))
        except:
            lista_urls.append(np.nan)
    
    ### Accedemos a los nombres de los productos 
    
    lista_nombres=list()
    for i in range(len(productos)):
        try:
            lista_nombres.append(productos[i].find_elements_by_tag_name("a")[1].text)
        except:
            lista_nombres.append(np.nan)
    
    ### Accedemos a los precios de los productos
    
    lista_precios=list()
    lista_promos=list()

    for i in range(len(productos)):
        try:
            lista_precios.append(productos[i].find_elements_by_class_name("price")[0].text)
        except:
            lista_precios.append(np.nan)
        try:
            lista_promos.append(productos[i].find_elements_by_class_name("price")[1].text)
        except:
            lista_promos.append(np.nan)
    
    ### Pasamos toda la informacion de los productos a al documento Excel
    
    df_proyecto = pd.DataFrame({"Nombre":lista_nombres,"URL":lista_urls,"Precio":lista_precios,"Precio con descuento":lista_promos})
    df_proyecto["Farmacia"]="Del Ahorro"
    df_proyecto["Medicamento"]= producto
    df_proyecto["Fecha"]= time.strftime("%d/%m/%y")
    df_proyecto = df_proyecto[["Fecha","Farmacia","Medicamento","Nombre","URL","Precio","Precio con descuento"]]

    ### Una vez pasado convertimos la info a flotante y cerramos la ventana de Chrome

    df_proyecto = df_proyecto[df_proyecto["Nombre"].astype(str).str.contains(r'\b{}\b'.format(producto), regex=True, case=False)]
    df_proyecto  =df_proyecto.reset_index(drop=True)

    datos_webscraper=pd.read_excel("df_proyecto.xlsx")
    datos_webscraper= pd.concat([datos_webscraper,df_proyecto],axis=0)
    datos_webscraper.to_excel("df_proyecto.xlsx",index=False)
    driver.quit()

    return df_proyecto




def precios_floats(datos):                                                              # | Creamos una funcion que convertira la infromacion en flotantes
    
    ### Iteramos sobre la informacion convirtiendola en flotantes
    
    for i in range(len(datos["Precio con descuento"])):
        try:
            datos["Precio con descuento"].iloc[i]=datos["Precio con descuento"].iloc[i].strip("$MXN")
        except:
            pass
        
    for i in range(len(datos["Precio"])):
        try:
            datos["Precio"].iloc[i]=datos["Precio"].iloc[i].strip("$MXN")
        except:
            pass
    ###  Guardamos la nueva informacion en el documento Excel 
    
    datos["Precio con descuento"]=datos["Precio con descuento"].replace(",","",regex=True)
    datos["Precio"]=datos["Precio"].replace(",","",regex=True)
      
    datos['Precio con descuento'] = pd.to_numeric(datos['Precio con descuento'], errors='coerce')
    datos['Precio'] = pd.to_numeric(datos['Precio'], errors='coerce')

    datos.to_excel("df_proyectobien.xlsx",index=False)
    return ldatos

    
    

def Precios(path):    # | Creamos una funcion que hara llamar la funciones anteriores ademas de graficar los precios
    for productos in ["PARACETAMOL 500 MG", "CLONAZEPAM","VIAGRA", "IBUPROFENO 400 MG"]:   # | Medicamentos a buscar
        Buscador_Precios_FGuadalajara(productos,path)
        Buscador_Precios_Selenium_sanpablo(productos,path)
        Buscador_Precios_Selenium_FAhorro(productos,path)
    
    ### Graficamos la diferencia de precios de los medicamentos mas baratos encontrados entre las farmacias
    
    fig, ax = plt.subplots()
    plt.bar(range(3), [38, 15, 35], color=["red","blue","grey"],align='center')
    plt.title("Comparación del menor precio Ibuprofeno",fontsize=20)
    names = ["Ahorro","Guadalajara","San Pablo"]
    ax.set_xticks(range(3))
    ax.set_xticklabels(names)
    plt.show()

    fig, ax = plt.subplots()
    plt.bar(range(3), [20, 5.5, 9.5], color=["red","blue","grey"],align='center')
    plt.title("Comparación del menor precio Paracetamol",fontsize=20)
    names = ["Ahorro","Guadalajara","San Pablo"]
    ax.set_xticks(range(3))
    ax.set_xticklabels(names)
    plt.show()

    fig, ax = plt.subplots()
    plt.bar(range(3), [79, 63, 94], color=["red","blue","grey"],align='center')
    plt.title("Comparación del menor precio Clonazepam",fontsize=20)
    names = ["Ahorro","Guadalajara","San Pablo"]
    ax.set_xticks(range(3))
    ax.set_xticklabels(names)
    plt.show()

    fig, ax = plt.subplots()
    plt.bar(range(3), [225, 216, 205], color=["red","blue","grey"],align='center')
    plt.title("Comparación del menor precio Viagra",fontsize=20)
    names = ["Ahorro","Guadalajara","San Pablo"]
    ax.set_xticks(range(3))
    ax.set_xticklabels(names)
    plt.show()

# %%
# | Direccion donde este guardado el Chrome Driver Ejemplo: "C:\WebDriver\chromedriver.exe"
Precios("C:\webdriver4\chromedriver.exe")

precios_floats(df_proyecto)
df_proyecto=pd.read_excel("df_proyectobien.xlsx")
# Out:
# C:\Users\abima\AppData\Local\Temp/ipykernel_28028/2929883508.py:13: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(path)

# %%
df_proyecto
# Out:
#        Fecha     Farmacia         Medicamento  \
# 0   26/01/22  Guadalajara  PARACETAMOL 500 MG
# 1   26/01/22  Guadalajara  PARACETAMOL 500 MG
# 2   26/01/22  Guadalajara  PARACETAMOL 500 MG
# 3   26/01/22    San Pablo  PARACETAMOL 500 MG
# 4   26/01/22    San Pablo  PARACETAMOL 500 MG
# 5   26/01/22    San Pablo  PARACETAMOL 500 MG
# 6   26/01/22    San Pablo  PARACETAMOL 500 MG
# 7   26/01/22    San Pablo  PARACETAMOL 500 MG
# 8   26/01/22    San Pablo  PARACETAMOL 500 MG
# 9   26/01/22   Del Ahorro  PARACETAMOL 500 MG
# 10  26/01/22   Del Ahorro  PARACETAMOL 500 MG
# 11  26/01/22   Del Ahorro  PARACETAMOL 500 MG
# 12  26/01/22   Del Ahorro  PARACETAMOL 500 MG
# 13  26/01/22   Del Ahorro  PARACETAMOL 500 MG
# 14  26/01/22  Guadalajara          CLONAZEPAM
# 15  26/01/22  Guadalajara          CLONAZEPAM
# 16  26/01/22  Guadalajara          CLONAZEPAM
# 17  26/01/22  Guadalajara          CLONAZEPAM
# 18  26/01/22  Guadalajara          CLONAZEPAM
# 19  26/01/22  Guadalajara          CLONAZEPAM
# 20  26/01/22  Guadalajara          CLONAZEPAM
# 21  26/01/22  Guadalajara          CLONAZEPAM
# 22  26/01/22  Guadalajara          CLONAZEPAM
# 23  26/01/22  Guadalajara          CLONAZEPAM
# 24  26/01/22  Guadalajara          CLONAZEPAM
# 25  26/01/22  Guadalajara          CLONAZEPAM
# 26  26/01/22  Guadalajara          CLONAZEPAM
# 27  26/01/22    San Pablo          CLONAZEPAM
# 28  26/01/22    San Pablo          CLONAZEPAM
# 29  26/01/22   Del Ahorro          CLONAZEPAM
# 30  26/01/22  Guadalajara              VIAGRA
# 31  26/01/22  Guadalajara              VIAGRA
# 32  26/01/22  Guadalajara              VIAGRA
# 33  26/01/22  Guadalajara              VIAGRA
# 34  26/01/22  Guadalajara              VIAGRA
# 35  26/01/22  Guadalajara              VIAGRA
# 36  26/01/22  Guadalajara              VIAGRA
# 37  26/01/22    San Pablo              VIAGRA
# 38  26/01/22    San Pablo              VIAGRA
# 39  26/01/22    San Pablo              VIAGRA
# 40  26/01/22    San Pablo              VIAGRA
# 41  26/01/22    San Pablo              VIAGRA
# 42  26/01/22    San Pablo              VIAGRA
# 43  26/01/22    San Pablo              VIAGRA
# 44  26/01/22   Del Ahorro              VIAGRA
# 45  26/01/22   Del Ahorro              VIAGRA
# 46  26/01/22   Del Ahorro              VIAGRA
# 47  26/01/22   Del Ahorro              VIAGRA
# 48  26/01/22   Del Ahorro              VIAGRA
# 49  26/01/22   Del Ahorro              VIAGRA
# 50  26/01/22   Del Ahorro              VIAGRA
# 51  26/01/22   Del Ahorro              VIAGRA
# 52  26/01/22  Guadalajara   IBUPROFENO 400 MG
# 53  26/01/22  Guadalajara   IBUPROFENO 400 MG
# 54  26/01/22  Guadalajara   IBUPROFENO 400 MG
# 55  26/01/22    San Pablo   IBUPROFENO 400 MG
# 56  26/01/22    San Pablo   IBUPROFENO 400 MG
# 57  26/01/22   Del Ahorro   IBUPROFENO 400 MG
# 58  26/01/22   Del Ahorro   IBUPROFENO 400 MG
#
#                                                Nombre  \
# 0                      Paracetamol 500mg 100 Tabletas
# 1            Paracetamol 500mg 20 Tabletas Pharmalife
# 2            Paracetamol 500mg 10 Tabletas Pharmalife
# 3                                  PARACETAMOL 500 MG
# 4                                  PARACETAMOL 500 MG
# 5           BUTILHIOSCINA 10 MG PARACETAMOL 500 MG MG
# 6                    PARACETAMOL 500 MG CAFEÍNA 50 MG
# 7                    PARACETAMOL 500 MG CAFEÍNA 50 MG
# 8   PARACETAMOL 500 MG CAFEÍNA 25 MG FENILEFRINA 5 MG
# 9   Marca del Ahorro Paracetamol 500 mg oral 100 t...
# 10  Marca del Ahorro Paracetamol 500 mg oral 20 ta...
# 11  Marca del Ahorro Paracetamol 500 mg oral 10 ta...
# 12  Desenfriol-D® antigripal Paracetamol 500 MG 24...
# 13  Desenfriol-D® antigripal Paracetamol 500 MG 12...
# 14                         Clonazepam 2mg 30 Tabletas
# 15                         Clonazepam 2mg 30 Tabletas
# 16              Clonazepam 2mg 30 Tabletas Pharmalife
# 17                   Clonazepam 2.5mg 10ml Pharmalife
# 18                    Kriadex 2.5mg/1ml 10ml Solución
# 19                             Klodex 2mg 30 Tabletas
# 20             Rivotril Solución 2.5mg/ml 10ml Gotero
# 21                        Rivotril 2mg 30 Comprimidos
# 22                       Rivotril 2mg 100 Comprimidos
# 23                            Kriadex 2mg 60 Tabletas
# 24                    Kriadex Solución 2.5mg/1ml 20ml
# 25                            Kriadex 2mg 30 Tabletas
# 26                      Klodex 2.5mg/ml Solución 10ml
# 27                                  CLONAZEPAM 2.5 MG
# 28                                    CLONAZEPAM 2 MG
# 29         MARCA DEL AHORRO CLONAZEPAM 2MG 30TABLETAS
# 30                             Viagra 100mg 1 Tableta
# 31                            Viagra 100mg 4 Tabletas
# 32               Viagra Jet 50mg 1 Tableta Masticable
# 33            Viagra Jet 100mg 4 Tabletas Masticables
# 34            Viagra Jet 100mg 2 Tabletas Masticables
# 35                            Viagra 100mg 2 Tabletas
# 36                              Viagra 50mg 1 Tableta
# 37                           VIAGRA 4 TABLETA BLÍSTER
# 38                              VIAGRA 1 TABLETA CAJA
# 39                           VIAGRA 4 TABLETA BLÍSTER
# 40                           VIAGRA 1 TABLETA BLÍSTER
# 41                         VIAGRA JET 2 TABLETAS CAJA
# 42                         VIAGRA JET 4 TABLETAS CAJA
# 43    VIAGRA 2 CAJAS CON UNA TABLETA CADA UNA PAQUETE
# 44                      Viagra 50 Mg. Oral 4 Tabletas
# 45                      Viagra 50 Mg. Oral 1 Tabletas
# 46                     Viagra 100 Mg. Oral 4 Tabletas
# 47                     Viagra 100 Mg. Oral 2 Tabletas
# 48                     Viagra 100 Mg. Oral 1 Tabletas
# 49      Viagra Jet 50 Mg. Oral 4 Tabletas Masticables
# 50     Viagra Jet 100 Mg. Oral 4 Tabletas Masticables
# 51     Viagra Jet 100 Mg. Oral 2 Tabletas Masticables
# 52            Ibuprofeno 400mg 10 Tabletas Pharmalife
# 53            Ibuprofeno 400mg 20 Tabletas Pharmalife
# 54            Ibuprofeno 400mg 10 Cápsulas Pharmalife
# 55                                  IBUPROFENO 400 MG
# 56                                  IBUPROFENO 400 MG
# 57     Marca del Ahorro Ibuprofeno 400 mg 10 cápsulas
# 58  Marca del Ahorro Ibuprofeno 400 mg oral 20 tab...
#
#                                                   URL   Precio  \
# 0   http://www.farmaciasguadalajara.com/es/farmaci...   229.80
# 1   http://www.farmaciasguadalajara.com/es/farmaci...    35.51
# 2   http://www.farmaciasguadalajara.com/es/farmaci...    22.00
# 3   https://www.farmaciasanpablo.com.mx/medicament...    10.00
# 4   https://www.farmaciasanpablo.com.mx/medicament...     9.50
# 5   https://www.farmaciasanpablo.com.mx/medicament...    97.00
# 6   https://www.farmaciasanpablo.com.mx/medicament...    32.50
# 7   https://www.farmaciasanpablo.com.mx/medicament...    26.00
# 8   https://www.farmaciasanpablo.com.mx/medicament...    32.00
# 9   https://www.fahorro.com/paracetamol-500-mg-ora...    94.00
# 10  https://www.fahorro.com/paracetamol-500-mg-ora...    26.00
# 11  https://www.fahorro.com/paracetamol-500-mg-ora...    20.00
# 12  https://www.fahorro.com/desenfriol-d-oral-24-t...    44.00
# 13  https://www.fahorro.com/desenfriol-d-12-tablet...    29.00
# 14  http://www.farmaciasguadalajara.com/es/farmaci...   392.05
# 15  http://www.farmaciasguadalajara.com/ProductDis...   254.00
# 16  http://www.farmaciasguadalajara.com/es/farmaci...   720.00
# 17  http://www.farmaciasguadalajara.com/es/farmaci...   491.40
# 18  http://www.farmaciasguadalajara.com/es/farmaci...   254.00
# 19  http://www.farmaciasguadalajara.com/es/farmaci...   690.00
# 20  http://www.farmaciasguadalajara.com/es/farmaci...   608.00
# 21  http://www.farmaciasguadalajara.com/es/farmaci...   890.00
# 22  http://www.farmaciasguadalajara.com/es/farmaci...  2291.00
# 23  http://www.farmaciasguadalajara.com/es/farmaci...   658.00
# 24  http://www.farmaciasguadalajara.com/es/farmaci...   381.00
# 25  http://www.farmaciasguadalajara.com/es/farmaci...   408.00
# 26  http://www.farmaciasguadalajara.com/es/farmaci...   470.00
# 27  https://www.farmaciasanpablo.com.mx/medicament...   159.00
# 28  https://www.farmaciasanpablo.com.mx/medicament...    94.00
# 29  https://www.fahorro.com/marca-del-ahorro-clona...    79.00
# 30  http://www.farmaciasguadalajara.com/es/farmaci...   330.80
# 31  http://www.farmaciasguadalajara.com/es/farmaci...  1092.29
# 32  http://www.farmaciasguadalajara.com/es/farmaci...   314.62
# 33  http://www.farmaciasguadalajara.com/es/farmaci...  1164.61
# 34  http://www.farmaciasguadalajara.com/es/farmaci...   646.01
# 35  http://www.farmaciasguadalajara.com/es/farmaci...   549.12
# 36  http://www.farmaciasguadalajara.com/es/farmaci...   297.72
# 37  https://www.farmaciasanpablo.com.mx/medicament...   725.50
# 38  https://www.farmaciasanpablo.com.mx/medicament...   205.00
# 39  https://www.farmaciasanpablo.com.mx/medicament...   770.00
# 40  https://www.farmaciasanpablo.com.mx/medicament...   221.50
# 41  https://www.farmaciasanpablo.com.mx/medicament...   521.00
# 42  https://www.farmaciasanpablo.com.mx/medicament...   891.00
# 43  https://www.farmaciasanpablo.com.mx/medicament...   417.50
# 44  https://www.fahorro.com/viagra-50-mg-oral-4-ta...   727.00
# 45  https://www.fahorro.com/viagra-50-mg-oral-1-ta...   225.00
# 46  https://www.fahorro.com/viagra-100-mg-oral-4-t...   808.00
# 47  https://www.fahorro.com/viagra-100-mg-oral-2-t...   422.00
# 48  https://www.fahorro.com/viagra-100-mg-oral-1-t...   236.00
# 49  https://www.fahorro.com/viagra-jet-50-mg-oral-...   888.00
# 50  https://www.fahorro.com/viagra-jet-100-mg-oral...   995.00
# 51  https://www.fahorro.com/viagra-jet-100-mg-oral...   556.00
# 52  http://www.farmaciasguadalajara.com/es/farmaci...    84.15
# 53  http://www.farmaciasguadalajara.com/es/farmaci...   177.24
# 54  http://www.farmaciasguadalajara.com/es/farmaci...    83.60
# 55  https://www.farmaciasanpablo.com.mx/medicament...    35.00
# 56  https://www.farmaciasanpablo.com.mx/medicament...    35.00
# 57  https://www.fahorro.com/g-ahorro-ibuprofeno-40...    38.00
# 58  https://www.fahorro.com/ibuprofeno-400-mg-oral...    54.00
#
#     Precio con descuento
# 0                  60.99
# 1                  14.00
# 2                   5.50
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                 81.00
# 15                203.20
# 16                 62.93
# 17                101.52
# 18                203.20
# 19                116.47
# 20                486.40
# 21                712.00
# 22               1832.80
# 23                526.40
# 24                304.80
# 25                326.40
# 26                106.88
# 27                   NaN
# 28                   NaN
# 29                   NaN
# 30                216.67
# 31                715.45
# 32                169.01
# 33                625.86
# 34                346.97
# 35                365.16
# 36                195.01
# 37                   NaN
# 38                   NaN
# 39                   NaN
# 40                   NaN
# 41                   NaN
# 42                   NaN
# 43                   NaN
# 44                   NaN
# 45                   NaN
# 46                   NaN
# 47                   NaN
# 48                   NaN
# 49                   NaN
# 50                   NaN
# 51                   NaN
# 52                 15.50
# 53                 28.50
# 54                 15.90
# 55                   NaN
# 56                   NaN
# 57                   NaN
# 58                   NaN

# %%
#Esta consulta nos limita a 10 resultados 
ps.sqldf("select  * from df_proyecto where (Medicamento= 'PARACETAMOL 500 MG') limit 10")#SI
# Out:
#       Fecha     Farmacia         Medicamento  \
# 0  26/01/22  Guadalajara  PARACETAMOL 500 MG
# 1  26/01/22  Guadalajara  PARACETAMOL 500 MG
# 2  26/01/22  Guadalajara  PARACETAMOL 500 MG
# 3  26/01/22    San Pablo  PARACETAMOL 500 MG
# 4  26/01/22    San Pablo  PARACETAMOL 500 MG
# 5  26/01/22    San Pablo  PARACETAMOL 500 MG
# 6  26/01/22    San Pablo  PARACETAMOL 500 MG
# 7  26/01/22    San Pablo  PARACETAMOL 500 MG
# 8  26/01/22    San Pablo  PARACETAMOL 500 MG
# 9  26/01/22   Del Ahorro  PARACETAMOL 500 MG
#
#                                               Nombre  \
# 0                     Paracetamol 500mg 100 Tabletas
# 1           Paracetamol 500mg 20 Tabletas Pharmalife
# 2           Paracetamol 500mg 10 Tabletas Pharmalife
# 3                                 PARACETAMOL 500 MG
# 4                                 PARACETAMOL 500 MG
# 5          BUTILHIOSCINA 10 MG PARACETAMOL 500 MG MG
# 6                   PARACETAMOL 500 MG CAFEÍNA 50 MG
# 7                   PARACETAMOL 500 MG CAFEÍNA 50 MG
# 8  PARACETAMOL 500 MG CAFEÍNA 25 MG FENILEFRINA 5 MG
# 9  Marca del Ahorro Paracetamol 500 mg oral 100 t...
#
#                                                  URL  Precio  \
# 0  http://www.farmaciasguadalajara.com/es/farmaci...  229.80
# 1  http://www.farmaciasguadalajara.com/es/farmaci...   35.51
# 2  http://www.farmaciasguadalajara.com/es/farmaci...   22.00
# 3  https://www.farmaciasanpablo.com.mx/medicament...   10.00
# 4  https://www.farmaciasanpablo.com.mx/medicament...    9.50
# 5  https://www.farmaciasanpablo.com.mx/medicament...   97.00
# 6  https://www.farmaciasanpablo.com.mx/medicament...   32.50
# 7  https://www.farmaciasanpablo.com.mx/medicament...   26.00
# 8  https://www.farmaciasanpablo.com.mx/medicament...   32.00
# 9  https://www.fahorro.com/paracetamol-500-mg-ora...   94.00
#
#    Precio con descuento
# 0                 60.99
# 1                 14.00
# 2                  5.50
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN

# %%
#Esta consulta nos muestra los medicamentos de todas las farmacias con precio menor a 150 pesos
ps.sqldf("select *  from df_proyecto where  Precio <150  ") #SI
# Out:
#        Fecha     Farmacia         Medicamento  \
# 0   26/01/22  Guadalajara  PARACETAMOL 500 MG
# 1   26/01/22  Guadalajara  PARACETAMOL 500 MG
# 2   26/01/22    San Pablo  PARACETAMOL 500 MG
# 3   26/01/22    San Pablo  PARACETAMOL 500 MG
# 4   26/01/22    San Pablo  PARACETAMOL 500 MG
# 5   26/01/22    San Pablo  PARACETAMOL 500 MG
# 6   26/01/22    San Pablo  PARACETAMOL 500 MG
# 7   26/01/22    San Pablo  PARACETAMOL 500 MG
# 8   26/01/22   Del Ahorro  PARACETAMOL 500 MG
# 9   26/01/22   Del Ahorro  PARACETAMOL 500 MG
# 10  26/01/22   Del Ahorro  PARACETAMOL 500 MG
# 11  26/01/22   Del Ahorro  PARACETAMOL 500 MG
# 12  26/01/22   Del Ahorro  PARACETAMOL 500 MG
# 13  26/01/22    San Pablo          CLONAZEPAM
# 14  26/01/22   Del Ahorro          CLONAZEPAM
# 15  26/01/22  Guadalajara   IBUPROFENO 400 MG
# 16  26/01/22  Guadalajara   IBUPROFENO 400 MG
# 17  26/01/22    San Pablo   IBUPROFENO 400 MG
# 18  26/01/22    San Pablo   IBUPROFENO 400 MG
# 19  26/01/22   Del Ahorro   IBUPROFENO 400 MG
# 20  26/01/22   Del Ahorro   IBUPROFENO 400 MG
#
#                                                Nombre  \
# 0            Paracetamol 500mg 20 Tabletas Pharmalife
# 1            Paracetamol 500mg 10 Tabletas Pharmalife
# 2                                  PARACETAMOL 500 MG
# 3                                  PARACETAMOL 500 MG
# 4           BUTILHIOSCINA 10 MG PARACETAMOL 500 MG MG
# 5                    PARACETAMOL 500 MG CAFEÍNA 50 MG
# 6                    PARACETAMOL 500 MG CAFEÍNA 50 MG
# 7   PARACETAMOL 500 MG CAFEÍNA 25 MG FENILEFRINA 5 MG
# 8   Marca del Ahorro Paracetamol 500 mg oral 100 t...
# 9   Marca del Ahorro Paracetamol 500 mg oral 20 ta...
# 10  Marca del Ahorro Paracetamol 500 mg oral 10 ta...
# 11  Desenfriol-D® antigripal Paracetamol 500 MG 24...
# 12  Desenfriol-D® antigripal Paracetamol 500 MG 12...
# 13                                    CLONAZEPAM 2 MG
# 14         MARCA DEL AHORRO CLONAZEPAM 2MG 30TABLETAS
# 15            Ibuprofeno 400mg 10 Tabletas Pharmalife
# 16            Ibuprofeno 400mg 10 Cápsulas Pharmalife
# 17                                  IBUPROFENO 400 MG
# 18                                  IBUPROFENO 400 MG
# 19     Marca del Ahorro Ibuprofeno 400 mg 10 cápsulas
# 20  Marca del Ahorro Ibuprofeno 400 mg oral 20 tab...
#
#                                                   URL  Precio  \
# 0   http://www.farmaciasguadalajara.com/es/farmaci...   35.51
# 1   http://www.farmaciasguadalajara.com/es/farmaci...   22.00
# 2   https://www.farmaciasanpablo.com.mx/medicament...   10.00
# 3   https://www.farmaciasanpablo.com.mx/medicament...    9.50
# 4   https://www.farmaciasanpablo.com.mx/medicament...   97.00
# 5   https://www.farmaciasanpablo.com.mx/medicament...   32.50
# 6   https://www.farmaciasanpablo.com.mx/medicament...   26.00
# 7   https://www.farmaciasanpablo.com.mx/medicament...   32.00
# 8   https://www.fahorro.com/paracetamol-500-mg-ora...   94.00
# 9   https://www.fahorro.com/paracetamol-500-mg-ora...   26.00
# 10  https://www.fahorro.com/paracetamol-500-mg-ora...   20.00
# 11  https://www.fahorro.com/desenfriol-d-oral-24-t...   44.00
# 12  https://www.fahorro.com/desenfriol-d-12-tablet...   29.00
# 13  https://www.farmaciasanpablo.com.mx/medicament...   94.00
# 14  https://www.fahorro.com/marca-del-ahorro-clona...   79.00
# 15  http://www.farmaciasguadalajara.com/es/farmaci...   84.15
# 16  http://www.farmaciasguadalajara.com/es/farmaci...   83.60
# 17  https://www.farmaciasanpablo.com.mx/medicament...   35.00
# 18  https://www.farmaciasanpablo.com.mx/medicament...   35.00
# 19  https://www.fahorro.com/g-ahorro-ibuprofeno-40...   38.00
# 20  https://www.fahorro.com/ibuprofeno-400-mg-oral...   54.00
#
#     Precio con descuento
# 0                   14.0
# 1                    5.5
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                  15.5
# 16                  15.9
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN

# %%
#Esta consulta nos muestra todos los medicamentos de la farmacia Guadalajara
ps.sqldf("select  * from df_proyecto where (Farmacia = 'Guadalajara') ")#si
# Out:
#        Fecha     Farmacia         Medicamento  \
# 0   26/01/22  Guadalajara  PARACETAMOL 500 MG
# 1   26/01/22  Guadalajara  PARACETAMOL 500 MG
# 2   26/01/22  Guadalajara  PARACETAMOL 500 MG
# 3   26/01/22  Guadalajara          CLONAZEPAM
# 4   26/01/22  Guadalajara          CLONAZEPAM
# 5   26/01/22  Guadalajara          CLONAZEPAM
# 6   26/01/22  Guadalajara          CLONAZEPAM
# 7   26/01/22  Guadalajara          CLONAZEPAM
# 8   26/01/22  Guadalajara          CLONAZEPAM
# 9   26/01/22  Guadalajara          CLONAZEPAM
# 10  26/01/22  Guadalajara          CLONAZEPAM
# 11  26/01/22  Guadalajara          CLONAZEPAM
# 12  26/01/22  Guadalajara          CLONAZEPAM
# 13  26/01/22  Guadalajara          CLONAZEPAM
# 14  26/01/22  Guadalajara          CLONAZEPAM
# 15  26/01/22  Guadalajara          CLONAZEPAM
# 16  26/01/22  Guadalajara              VIAGRA
# 17  26/01/22  Guadalajara              VIAGRA
# 18  26/01/22  Guadalajara              VIAGRA
# 19  26/01/22  Guadalajara              VIAGRA
# 20  26/01/22  Guadalajara              VIAGRA
# 21  26/01/22  Guadalajara              VIAGRA
# 22  26/01/22  Guadalajara              VIAGRA
# 23  26/01/22  Guadalajara   IBUPROFENO 400 MG
# 24  26/01/22  Guadalajara   IBUPROFENO 400 MG
# 25  26/01/22  Guadalajara   IBUPROFENO 400 MG
#
#                                       Nombre  \
# 0             Paracetamol 500mg 100 Tabletas
# 1   Paracetamol 500mg 20 Tabletas Pharmalife
# 2   Paracetamol 500mg 10 Tabletas Pharmalife
# 3                 Clonazepam 2mg 30 Tabletas
# 4                 Clonazepam 2mg 30 Tabletas
# 5      Clonazepam 2mg 30 Tabletas Pharmalife
# 6           Clonazepam 2.5mg 10ml Pharmalife
# 7            Kriadex 2.5mg/1ml 10ml Solución
# 8                     Klodex 2mg 30 Tabletas
# 9     Rivotril Solución 2.5mg/ml 10ml Gotero
# 10               Rivotril 2mg 30 Comprimidos
# 11              Rivotril 2mg 100 Comprimidos
# 12                   Kriadex 2mg 60 Tabletas
# 13           Kriadex Solución 2.5mg/1ml 20ml
# 14                   Kriadex 2mg 30 Tabletas
# 15             Klodex 2.5mg/ml Solución 10ml
# 16                    Viagra 100mg 1 Tableta
# 17                   Viagra 100mg 4 Tabletas
# 18      Viagra Jet 50mg 1 Tableta Masticable
# 19   Viagra Jet 100mg 4 Tabletas Masticables
# 20   Viagra Jet 100mg 2 Tabletas Masticables
# 21                   Viagra 100mg 2 Tabletas
# 22                     Viagra 50mg 1 Tableta
# 23   Ibuprofeno 400mg 10 Tabletas Pharmalife
# 24   Ibuprofeno 400mg 20 Tabletas Pharmalife
# 25   Ibuprofeno 400mg 10 Cápsulas Pharmalife
#
#                                                   URL   Precio  \
# 0   http://www.farmaciasguadalajara.com/es/farmaci...   229.80
# 1   http://www.farmaciasguadalajara.com/es/farmaci...    35.51
# 2   http://www.farmaciasguadalajara.com/es/farmaci...    22.00
# 3   http://www.farmaciasguadalajara.com/es/farmaci...   392.05
# 4   http://www.farmaciasguadalajara.com/ProductDis...   254.00
# 5   http://www.farmaciasguadalajara.com/es/farmaci...   720.00
# 6   http://www.farmaciasguadalajara.com/es/farmaci...   491.40
# 7   http://www.farmaciasguadalajara.com/es/farmaci...   254.00
# 8   http://www.farmaciasguadalajara.com/es/farmaci...   690.00
# 9   http://www.farmaciasguadalajara.com/es/farmaci...   608.00
# 10  http://www.farmaciasguadalajara.com/es/farmaci...   890.00
# 11  http://www.farmaciasguadalajara.com/es/farmaci...  2291.00
# 12  http://www.farmaciasguadalajara.com/es/farmaci...   658.00
# 13  http://www.farmaciasguadalajara.com/es/farmaci...   381.00
# 14  http://www.farmaciasguadalajara.com/es/farmaci...   408.00
# 15  http://www.farmaciasguadalajara.com/es/farmaci...   470.00
# 16  http://www.farmaciasguadalajara.com/es/farmaci...   330.80
# 17  http://www.farmaciasguadalajara.com/es/farmaci...  1092.29
# 18  http://www.farmaciasguadalajara.com/es/farmaci...   314.62
# 19  http://www.farmaciasguadalajara.com/es/farmaci...  1164.61
# 20  http://www.farmaciasguadalajara.com/es/farmaci...   646.01
# 21  http://www.farmaciasguadalajara.com/es/farmaci...   549.12
# 22  http://www.farmaciasguadalajara.com/es/farmaci...   297.72
# 23  http://www.farmaciasguadalajara.com/es/farmaci...    84.15
# 24  http://www.farmaciasguadalajara.com/es/farmaci...   177.24
# 25  http://www.farmaciasguadalajara.com/es/farmaci...    83.60
#
#     Precio con descuento
# 0                  60.99
# 1                  14.00
# 2                   5.50
# 3                  81.00
# 4                 203.20
# 5                  62.93
# 6                 101.52
# 7                 203.20
# 8                 116.47
# 9                 486.40
# 10                712.00
# 11               1832.80
# 12                526.40
# 13                304.80
# 14                326.40
# 15                106.88
# 16                216.67
# 17                715.45
# 18                169.01
# 19                625.86
# 20                346.97
# 21                365.16
# 22                195.01
# 23                 15.50
# 24                 28.50
# 25                 15.90

# %%
#Esta consulta nos muestra un medicamento de dos de las farmacias
ps.sqldf("select  * from df_proyecto where (Medicamento= 'PARACETAMOL 500 MG') and ((Farmacia = 'Guadalajara') or (Farmacia = 'San Pablo'))") #SI
# Out:
#       Fecha     Farmacia         Medicamento  \
# 0  26/01/22  Guadalajara  PARACETAMOL 500 MG
# 1  26/01/22  Guadalajara  PARACETAMOL 500 MG
# 2  26/01/22  Guadalajara  PARACETAMOL 500 MG
# 3  26/01/22    San Pablo  PARACETAMOL 500 MG
# 4  26/01/22    San Pablo  PARACETAMOL 500 MG
# 5  26/01/22    San Pablo  PARACETAMOL 500 MG
# 6  26/01/22    San Pablo  PARACETAMOL 500 MG
# 7  26/01/22    San Pablo  PARACETAMOL 500 MG
# 8  26/01/22    San Pablo  PARACETAMOL 500 MG
#
#                                               Nombre  \
# 0                     Paracetamol 500mg 100 Tabletas
# 1           Paracetamol 500mg 20 Tabletas Pharmalife
# 2           Paracetamol 500mg 10 Tabletas Pharmalife
# 3                                 PARACETAMOL 500 MG
# 4                                 PARACETAMOL 500 MG
# 5          BUTILHIOSCINA 10 MG PARACETAMOL 500 MG MG
# 6                   PARACETAMOL 500 MG CAFEÍNA 50 MG
# 7                   PARACETAMOL 500 MG CAFEÍNA 50 MG
# 8  PARACETAMOL 500 MG CAFEÍNA 25 MG FENILEFRINA 5 MG
#
#                                                  URL  Precio  \
# 0  http://www.farmaciasguadalajara.com/es/farmaci...  229.80
# 1  http://www.farmaciasguadalajara.com/es/farmaci...   35.51
# 2  http://www.farmaciasguadalajara.com/es/farmaci...   22.00
# 3  https://www.farmaciasanpablo.com.mx/medicament...   10.00
# 4  https://www.farmaciasanpablo.com.mx/medicament...    9.50
# 5  https://www.farmaciasanpablo.com.mx/medicament...   97.00
# 6  https://www.farmaciasanpablo.com.mx/medicament...   32.50
# 7  https://www.farmaciasanpablo.com.mx/medicament...   26.00
# 8  https://www.farmaciasanpablo.com.mx/medicament...   32.00
#
#    Precio con descuento
# 0                 60.99
# 1                 14.00
# 2                  5.50
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN

# %%
##Esta consulta nos muestra el promedio de los medicamentos
ps.sqldf("select Medicamento,avg(Precio) as preciopromedio from df_proyecto group by Medicamento ")#si
# Out:
#           Medicamento  preciopromedio
# 0          CLONAZEPAM      552.465625
# 1   IBUPROFENO 400 MG       72.427143
# 2  PARACETAMOL 500 MG       50.522143
# 3              VIAGRA      591.075909

# %%
#Esta consulta nos muestra un Medicamento de cada farmacia
ps.sqldf("select  * from df_proyecto where ((Medicamento= 'VIAGRA') and (Farmacia = 'Guadalajara'))  or ((Medicamento= 'CLONAZEPAM') and (Farmacia = 'Del Ahorro')) or ((Medicamento= 'IBUPROFENO 400 MG') and (Farmacia = 'San Pablo'))") #SI
# Out:
#       Fecha     Farmacia        Medicamento  \
# 0  26/01/22   Del Ahorro         CLONAZEPAM
# 1  26/01/22  Guadalajara             VIAGRA
# 2  26/01/22  Guadalajara             VIAGRA
# 3  26/01/22  Guadalajara             VIAGRA
# 4  26/01/22  Guadalajara             VIAGRA
# 5  26/01/22  Guadalajara             VIAGRA
# 6  26/01/22  Guadalajara             VIAGRA
# 7  26/01/22  Guadalajara             VIAGRA
# 8  26/01/22    San Pablo  IBUPROFENO 400 MG
# 9  26/01/22    San Pablo  IBUPROFENO 400 MG
#
#                                        Nombre  \
# 0  MARCA DEL AHORRO CLONAZEPAM 2MG 30TABLETAS
# 1                      Viagra 100mg 1 Tableta
# 2                     Viagra 100mg 4 Tabletas
# 3        Viagra Jet 50mg 1 Tableta Masticable
# 4     Viagra Jet 100mg 4 Tabletas Masticables
# 5     Viagra Jet 100mg 2 Tabletas Masticables
# 6                     Viagra 100mg 2 Tabletas
# 7                       Viagra 50mg 1 Tableta
# 8                           IBUPROFENO 400 MG
# 9                           IBUPROFENO 400 MG
#
#                                                  URL   Precio  \
# 0  https://www.fahorro.com/marca-del-ahorro-clona...    79.00
# 1  http://www.farmaciasguadalajara.com/es/farmaci...   330.80
# 2  http://www.farmaciasguadalajara.com/es/farmaci...  1092.29
# 3  http://www.farmaciasguadalajara.com/es/farmaci...   314.62
# 4  http://www.farmaciasguadalajara.com/es/farmaci...  1164.61
# 5  http://www.farmaciasguadalajara.com/es/farmaci...   646.01
# 6  http://www.farmaciasguadalajara.com/es/farmaci...   549.12
# 7  http://www.farmaciasguadalajara.com/es/farmaci...   297.72
# 8  https://www.farmaciasanpablo.com.mx/medicament...    35.00
# 9  https://www.farmaciasanpablo.com.mx/medicament...    35.00
#
#    Precio con descuento
# 0                   NaN
# 1                216.67
# 2                715.45
# 3                169.01
# 4                625.86
# 5                346.97
# 6                365.16
# 7                195.01
# 8                   NaN
# 9                   NaN

# %%
#Esta consulta nos muestra los Medicamentos de dos farmacias con precio menor a 100 pesos
ps.sqldf("select  * from df_proyecto where (Precio< 100) and ((Farmacia = 'Guadalajara') or (Farmacia = 'San Pablo'))") #SI
# Out:
#        Fecha     Farmacia         Medicamento  \
# 0   26/01/22  Guadalajara  PARACETAMOL 500 MG
# 1   26/01/22  Guadalajara  PARACETAMOL 500 MG
# 2   26/01/22    San Pablo  PARACETAMOL 500 MG
# 3   26/01/22    San Pablo  PARACETAMOL 500 MG
# 4   26/01/22    San Pablo  PARACETAMOL 500 MG
# 5   26/01/22    San Pablo  PARACETAMOL 500 MG
# 6   26/01/22    San Pablo  PARACETAMOL 500 MG
# 7   26/01/22    San Pablo  PARACETAMOL 500 MG
# 8   26/01/22    San Pablo          CLONAZEPAM
# 9   26/01/22  Guadalajara   IBUPROFENO 400 MG
# 10  26/01/22  Guadalajara   IBUPROFENO 400 MG
# 11  26/01/22    San Pablo   IBUPROFENO 400 MG
# 12  26/01/22    San Pablo   IBUPROFENO 400 MG
#
#                                                Nombre  \
# 0            Paracetamol 500mg 20 Tabletas Pharmalife
# 1            Paracetamol 500mg 10 Tabletas Pharmalife
# 2                                  PARACETAMOL 500 MG
# 3                                  PARACETAMOL 500 MG
# 4           BUTILHIOSCINA 10 MG PARACETAMOL 500 MG MG
# 5                    PARACETAMOL 500 MG CAFEÍNA 50 MG
# 6                    PARACETAMOL 500 MG CAFEÍNA 50 MG
# 7   PARACETAMOL 500 MG CAFEÍNA 25 MG FENILEFRINA 5 MG
# 8                                     CLONAZEPAM 2 MG
# 9             Ibuprofeno 400mg 10 Tabletas Pharmalife
# 10            Ibuprofeno 400mg 10 Cápsulas Pharmalife
# 11                                  IBUPROFENO 400 MG
# 12                                  IBUPROFENO 400 MG
#
#                                                   URL  Precio  \
# 0   http://www.farmaciasguadalajara.com/es/farmaci...   35.51
# 1   http://www.farmaciasguadalajara.com/es/farmaci...   22.00
# 2   https://www.farmaciasanpablo.com.mx/medicament...   10.00
# 3   https://www.farmaciasanpablo.com.mx/medicament...    9.50
# 4   https://www.farmaciasanpablo.com.mx/medicament...   97.00
# 5   https://www.farmaciasanpablo.com.mx/medicament...   32.50
# 6   https://www.farmaciasanpablo.com.mx/medicament...   26.00
# 7   https://www.farmaciasanpablo.com.mx/medicament...   32.00
# 8   https://www.farmaciasanpablo.com.mx/medicament...   94.00
# 9   http://www.farmaciasguadalajara.com/es/farmaci...   84.15
# 10  http://www.farmaciasguadalajara.com/es/farmaci...   83.60
# 11  https://www.farmaciasanpablo.com.mx/medicament...   35.00
# 12  https://www.farmaciasanpablo.com.mx/medicament...   35.00
#
#     Precio con descuento
# 0                   14.0
# 1                    5.5
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                   15.5
# 10                  15.9
# 11                   NaN
# 12                   NaN
